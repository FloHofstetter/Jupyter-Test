# %%
import numpy as np
import matplotlib.pyplot as  plt
import IPython.display

# %%
IPython.display.set_matplotlib_formats('pdf', 'svg')

# %%
a = np.arange(start=0.0, stop=2*np.pi, step=0.1)
b = np.sin(a)

# %%
plt.plot(a, b)
